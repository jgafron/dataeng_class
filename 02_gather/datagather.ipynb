# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from urllib.request import urlopen
from bs4 import BeautifulSoup

url = "http://www.hubertiming.com/results/2017GPTR10K"
html = urlopen(url)

# %%
soup = BeautifulSoup(html, 'lxml')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
title = soup.title
print(title)
# Out:
# <title>Race results for the 2017 Intel Great Place to Run \ Urban Clash Games!</title>

# %%
text = soup.get_text()
print(text)
# Out:
# Race results for the 2017 Intel Great Place to Run \ Urban Clash Games!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  2017 Intel Great Place to Run 10K \ Urban Clash Games
#  Hillsboro Stadium, Hillsboro, OR
#  June 2nd, 2017
#
#
#
#
#
#
#
#
#  Email
#                         timing@hubertiming.com with results questions. Please include your bib number if you have it.
#
#
#
#
#
#
#
#
#
# Huber Timing Home
#
#
#
#
#
# 10K:
#
#
# Finishers:
# 577
#
#
# Male:
# 414
#
#
# Female:
# 163
#
#
#
#
#
#
#
#
#
#
#  5K Individual
#  5K Team
#  10K Individual
#  10K Team
#  Summary
#
#
#
#
# Indvidual Results
#
#
#
# 10K Results
#
#
#
# Search:
#
# Search
# Division:
#
# Men
# Women
# Non-Binary
# Masters Men
# Masters Women
# Masters Non-Binary
#
# F 18-25
# F 26-35
# F 36-45
# F 46-55
# F Under 18
# M 18-25
# M 26-35
# M 36-45
# M 46-55
# M 55+
# M Under 18
#  Team:
#
# Unattached
# COLUMBIA TEAM A
# COLUMBIA TEAM B
# COLUMBIA TEAM C
# COLUMBIA TEAM D
# COLUMBIA TEAM E
# DTNA1
# DTNA2
# DTNA3
# ...

# %%
soup.find_all('a')
# Out:
# [<a href="mailto:timing@hubertiming.com">timing@hubertiming.com</a>,
#  <a href="https://www.hubertiming.com">Huber Timing Home</a>,
#  <a class="btn btn-primary btn-lg" href="/results/2017GPTR" role="button" style="margin: 0px 0px 5px 5px"><i aria-hidden="true" class="fa fa-user"></i> 5K Individual</a>,
#  <a class="btn btn-primary btn-lg" href="/results/team/2017GPTR" role="button" style="margin: 0px 0px 5px 5px"><i aria-hidden="true" class="fa fa-users"></i> 5K Team</a>,
#  <a class="btn btn-primary btn-lg" href="/results/team/2017GPTR10K" role="button" style="margin: 0px 0px 5px 5px"><i aria-hidden="true" class="fa fa-users"></i> 10K Team</a>,
#  <a class="btn btn-primary btn-lg" href="/results/summary/2017GPTR10K" role="button" style="margin: 0px 0px 5px 5px"><i class="fa fa-stream"></i> Summary</a>,
#  <a id="individual" name="individual"></a>,
#  <a data-url="/results/2017GPTR10K" href="#tabs-1" id="rootTab" style="font-size: 18px">10K Results</a>,
# ...

# %%
all_links = soup.find_all("a")
for link in all_links:
    print(link.get("href"))
# Out:
# mailto:timing@hubertiming.com
# https://www.hubertiming.com
# /results/2017GPTR
# /results/team/2017GPTR
# /results/team/2017GPTR10K
# /results/summary/2017GPTR10K
# None
# #tabs-1
# https://www.hubertiming.com/
# https://facebook.com/hubertiming/
# None

# %%
rows = soup.find_all('tr')
#print(rows[:10])
for row in rows:
    row_td = row.find_all('td')
print(row_td)
type(row_td)
# Out:
# [<td>577</td>, <td>443</td>, <td>
#
#                     LIBBY B MITCHELL
#
#                 </td>, <td>F</td>, <td>HILLSBORO</td>, <td>OR</td>, <td>1:41:18</td>, <td>1:42:10</td>, <td></td>]
# bs4.element.ResultSet

# %%
str_cells = str(row_td)
cleantext = BeautifulSoup(str_cells, 'lxml').get_text()
print(cleantext)
# Out:
# [577, 443,
#
#                     LIBBY B MITCHELL
#
#                 , F, HILLSBORO, OR, 1:41:18, 1:42:10, ]

# %%
import re

list_rows = []
for row in rows:
    cells = row.find_all('td')
    str_cells = str(cells)
    clean = re.compile('<.*?>')
    clean2 = (re.sub(clean, '',str_cells))
    list_rows.append(clean2)
print(clean2)
type(clean2)
# Out:
# [577, 443,
#
#                     LIBBY B MITCHELL
#
#                 , F, HILLSBORO, OR, 1:41:18, 1:42:10, ]
# str

# %%
df = pd.DataFrame(list_rows)
df.head(10)
# Out:
#                                                    0
# 0                                                 []
# 1                                  [Finishers:, 577]
# 2                                       [Male:, 414]
# 3                                     [Female:, 163]
# 4                                                 []
# 5  [1, 814, \r\n\r\n                    JARED WIL...
# 6  [2, 573, \r\n\r\n                    NATHAN A ...
# 7  [3, 687, \r\n\r\n                    FRANCISCO...
# 8  [4, 623, \r\n\r\n                    PAUL MORR...
# 9  [5, 569, \r\n\r\n                    DEREK G O...

# %%
df1 = df[0].str.split(',', expand=True)
df1.head(10)
# Out:
#              0      1                                                  2  \
# 0           []   None                                               None
# 1  [Finishers:   577]                                               None
# 2       [Male:   414]                                               None
# 3     [Female:   163]                                               None
# 4           []   None                                               None
# 5           [1    814   \r\n\r\n                    JARED WILSON\r\n\...
# 6           [2    573   \r\n\r\n                    NATHAN A SUSTERSI...
# 7           [3    687   \r\n\r\n                    FRANCISCO MAYA\r\...
# 8           [4    623   \r\n\r\n                    PAUL MORROW\r\n\r...
# 9           [5    569   \r\n\r\n                    DEREK G OSBORNE\r...
#
#       3           4     5       6       7  \
# 0  None        None  None    None    None
# 1  None        None  None    None    None
# ...

# %%
df1 = df1.replace(to_replace=[r"\r", r"\n"], value=["", ""], regex=True) 
df1[0] = df1[0].str.strip('[')
df1[2] = df1[2].str.strip('.*')
df1.head(10)
# Out:
#             0      1                                                  2     3  \
# 0           ]   None                                               None  None
# 1  Finishers:   577]                                               None  None
# 2       Male:   414]                                               None  None
# 3     Female:   163]                                               None  None
# 4           ]   None                                               None  None
# 5           1    814                       JARED WILSON                     M
# 6           2    573                       NATHAN A SUSTERSIC       ...     M
# 7           3    687                       FRANCISCO MAYA           ...     M
# 8           4    623                        PAUL MORROW                     M
# 9           5    569                       DEREK G OSBORNE          ...     M
#
#             4     5       6       7  \
# 0        None  None    None    None
# ...

# %%
col_labels = soup.find_all('th')

# %%
all_header = []
col_str = str(col_labels)
cleantext2 = BeautifulSoup(col_str, "lxml").get_text()
all_header.append(cleantext2)
print(all_header)
# Out:
# ['[Place, Bib, Name, Gender, City, State, Time, Gun Time, Team]']

# %%
df2 = pd.DataFrame(all_header)
df2.head()
# Out:
#                                                    0
# 0  [Place, Bib, Name, Gender, City, State, Time, ...

# %%
df3 = df2[0].str.split(',', expand=True)
df3.head()
# Out:
#         0     1      2        3      4       5      6          7       8
# 0  [Place   Bib   Name   Gender   City   State   Time   Gun Time   Team]

# %%
frames = [df3, df1]

df4 = pd.concat(frames)
df4.head(20)
# Out:
#              0      1                                                  2  \
# 0       [Place    Bib                                               Name
# 0            ]   None                                               None
# 1   Finishers:   577]                                               None
# 2        Male:   414]                                               None
# 3      Female:   163]                                               None
# 4            ]   None                                               None
# 5            1    814                       JARED WILSON
# 6            2    573                       NATHAN A SUSTERSIC       ...
# 7            3    687                       FRANCISCO MAYA           ...
# 8            4    623                        PAUL MORROW
# 9            5    569                       DEREK G OSBORNE          ...
# 10           6    642                       JONATHON TRAN            ...
# ...

# %%
df5 = df4.rename(columns=df4.iloc[0])
df5.head()
# Out:
#        [Place    Bib   Name   Gender   City   State   Time   Gun Time   Team]
# 0      [Place    Bib   Name   Gender   City   State   Time   Gun Time   Team]
# 0           ]   None   None     None   None    None   None       None    None
# 1  Finishers:   577]   None     None   None    None   None       None    None
# 2       Male:   414]   None     None   None    None   None       None    None
# 3     Female:   163]   None     None   None    None   None       None    None

# %%
df5.info()
df5.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 583 entries, 0 to 581
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   [Place     583 non-null    object
#  1    Bib       581 non-null    object
#  2    Name      578 non-null    object
#  3    Gender    578 non-null    object
#  4    City      578 non-null    object
#  5    State     578 non-null    object
#  6    Time      578 non-null    object
#  7    Gun Time  578 non-null    object
#  8    Team]     578 non-null    object
# dtypes: object(9)
# memory usage: 45.5+ KB
# (583, 9)

# %%
df6 = df5.dropna(axis=0, how='any')
df6.info()
df6.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 578 entries, 0 to 581
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   [Place     578 non-null    object
#  1    Bib       578 non-null    object
#  2    Name      578 non-null    object
#  3    Gender    578 non-null    object
#  4    City      578 non-null    object
#  5    State     578 non-null    object
#  6    Time      578 non-null    object
#  7    Gun Time  578 non-null    object
#  8    Team]     578 non-null    object
# dtypes: object(9)
# memory usage: 45.2+ KB
# (578, 9)

# %%
df7 = df6.drop(df6.index[0])
df7.head()
# Out:
#   [Place   Bib                                               Name  Gender  \
# 5      1   814                       JARED WILSON                       M
# 6      2   573                       NATHAN A SUSTERSIC       ...       M
# 7      3   687                       FRANCISCO MAYA           ...       M
# 8      4   623                        PAUL MORROW                       M
# 9      5   569                       DEREK G OSBORNE          ...       M
#
#          City  State    Time  Gun Time  \
# 5      TIGARD     OR   36:21     36:24
# 6    PORTLAND     OR   36:42     36:45
# 7    PORTLAND     OR   37:44     37:48
# 8   BEAVERTON     OR   38:34     38:37
# 9   HILLSBORO     OR   39:21     39:24
#
#                                                Team]
# 5
# 6                               INTEL TEAM F     ...
# 7
# 8
# 9                               INTEL TEAM F     ...

# %%
df7.rename(columns={'[Place': 'Place'},inplace=True)
df7.rename(columns={' Team]': 'Team'},inplace=True)
df7.head()
# Out:
#   Place   Bib                                               Name  Gender  \
# 5     1   814                       JARED WILSON                       M
# 6     2   573                       NATHAN A SUSTERSIC       ...       M
# 7     3   687                       FRANCISCO MAYA           ...       M
# 8     4   623                        PAUL MORROW                       M
# 9     5   569                       DEREK G OSBORNE          ...       M
#
#          City  State    Time  Gun Time  \
# 5      TIGARD     OR   36:21     36:24
# 6    PORTLAND     OR   36:42     36:45
# 7    PORTLAND     OR   37:44     37:48
# 8   BEAVERTON     OR   38:34     38:37
# 9   HILLSBORO     OR   39:21     39:24
#
#                                                 Team
# 5
# 6                               INTEL TEAM F     ...
# 7
# 8
# 9                               INTEL TEAM F     ...

# %%
df7['Team'] = df7['Team'].str.strip(']')
df7[' Time'] = df7[' Time'].str.replace(' ', '')
df7.head()
# Out:
#   Place   Bib                                               Name  Gender  \
# 5     1   814                       JARED WILSON                       M
# 6     2   573                       NATHAN A SUSTERSIC       ...       M
# 7     3   687                       FRANCISCO MAYA           ...       M
# 8     4   623                        PAUL MORROW                       M
# 9     5   569                       DEREK G OSBORNE          ...       M
#
#          City  State   Time  Gun Time  \
# 5      TIGARD     OR  36:21     36:24
# 6    PORTLAND     OR  36:42     36:45
# 7    PORTLAND     OR  37:44     37:48
# 8   BEAVERTON     OR  38:34     38:37
# 9   HILLSBORO     OR  39:21     39:24
#
#                                                 Team
# 5
# 6                               INTEL TEAM F     ...
# 7
# 8
# 9                               INTEL TEAM F     ...

# %%
time_list = df7[' Time'].tolist()

# %%
time_mins = []
for i in time_list:
    components = i.split(':')  # Split the time string into components based on ':'
    
    if len(components) == 2:
        # 'mm:ss' format (minutes and seconds)
        m, s = components
        math = (int(m) * 60 + int(s)) /60  # Convert minutes and seconds to total seconds
    elif len(components) == 3:
        # 'hh:mm:ss' format (hours, minutes, and seconds)
        h, m, s = components
        math = (int(h) * 3600 + int(m) * 60 + int(s)) /60  # Convert hours, minutes, and seconds to total seconds
    else:
        # Invalid format, handle accordingly (e.g., skip or log)
        print(f"Illegal format detected: '{i}'")
        continue
    
    time_mins.append(math)

# %%
print(time_mins)
# Out:
# [36.35, 36.7, 37.733333333333334, 38.56666666666667, 39.35, 39.81666666666667, 40.06666666666667, 40.083333333333336, 40.28333333333333, 40.35, 40.46666666666667, 40.6, 40.71666666666667, 41.016666666666666, 41.31666666666667, 41.71666666666667, 41.983333333333334, 42.38333333333333, 42.483333333333334, 42.583333333333336, 42.6, 42.61666666666667, 42.93333333333333, 43.43333333333333, 43.45, 43.666666666666664, 43.7, 43.71666666666667, 43.766666666666666, 43.766666666666666, 43.78333333333333, 43.78333333333333, 44.06666666666667, 44.083333333333336, 44.1, 44.11666666666667, 44.38333333333333, 44.63333333333333, 44.68333333333333, 44.7, 44.8, 45.05, 45.083333333333336, 45.166666666666664, 45.18333333333333, 45.18333333333333, 45.21666666666667, 45.233333333333334, 45.25, 45.28333333333333, 45.45, 45.46666666666667, 45.483333333333334, 45.6, 45.6, 45.666666666666664, 45.666666666666664, 45.81666666666667, 45.916666666666664, 46.03333333333333, 46.21666666666667, 46.333333333333336, 46
# ...

# %%
df7['Runner_mins'] = time_mins
df7.head()
# Out:
#   Place   Bib                                               Name  Gender  \
# 5     1   814                       JARED WILSON                       M
# 6     2   573                       NATHAN A SUSTERSIC       ...       M
# 7     3   687                       FRANCISCO MAYA           ...       M
# 8     4   623                        PAUL MORROW                       M
# 9     5   569                       DEREK G OSBORNE          ...       M
#
#          City  State   Time  Gun Time  \
# 5      TIGARD     OR  36:21     36:24
# 6    PORTLAND     OR  36:42     36:45
# 7    PORTLAND     OR  37:44     37:48
# 8   BEAVERTON     OR  38:34     38:37
# 9   HILLSBORO     OR  39:21     39:24
#
#                                                 Team  Runner_mins
# 5                                                       36.350000
# 6                               INTEL TEAM F     ...    36.700000
# 7                                                       37.733333
# ...

# %%
df7.describe(include=[np.number])
# Out:
#        Runner_mins
# count   577.000000
# mean     60.035933
# std      11.970623
# min      36.350000
# 25%      51.000000
# 50%      59.016667
# 75%      67.266667
# max     101.300000

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 15, 5


df7.boxplot(column='Runner_mins')
plt.grid(True, axis='y')
plt.ylabel('Time')
plt.xticks([1], ['Runners'])
# Out:
# ([<matplotlib.axis.XTick at 0x1f1a9b18520>], [Text(1, 0, 'Runners')])

# %%
x = df7['Runner_mins']
ax = sns.distplot(x, hist=True, kde=True, rug=False, color='m', bins=25, hist_kws={'edgecolor':'black'})
plt.show()
# Out:
# C:\Users\Mr. Grinch\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
f_fuko = df7.loc[df7[' Gender']==' F']['Runner_mins']
m_fuko = df7.loc[df7[' Gender']==' M']['Runner_mins']
sns.distplot(f_fuko, hist=True, kde=True, rug=False, hist_kws={'edgecolor':'black'}, label='Female')
sns.distplot(m_fuko, hist=False, kde=True, rug=False, hist_kws={'edgecolor':'black'}, label='Male')
plt.legend()
# Out:
# C:\Users\Mr. Grinch\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Mr. Grinch\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
g_stats = df7.groupby(" Gender", as_index=True).describe()
print(g_stats)
# Out:
#         Runner_mins                                                         \
#               count       mean        std        min        25%        50%
#  Gender
#  F            163.0  66.119223  12.184440  43.766667  58.758333  64.616667
#  M            414.0  57.640821  11.011857  36.350000  49.395833  55.791667
#
#
#                75%         max
#  Gender
#  F       72.058333  101.300000
#  M       64.804167   98.516667

# %%
df7.boxplot(column='Runner_mins', by=' Gender')
plt.ylabel('Chip Time')
plt.suptitle("")
# Out:
# Text(0.5, 0.98, '')

# %%
# %pwd
# Out:
# 'C:\\Users\\Mr. Grinch'
